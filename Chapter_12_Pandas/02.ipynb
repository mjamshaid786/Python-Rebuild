# %%
import pandas as pd

# %%
data = {
    'Name' : ['Ahmad', 'Ali', 'Hassan'],
    'Degree' : ['BSCS', 'BSIT', 'BSSE']
}

# %%
df = pd.DataFrame(data)

# %%
df.head(2)
# Out:
#     Name Degree
# 0  Ahmad   BSCS
# 1    Ali   BSIT

# %%
df.rename(columns={'Degree' : 'Class'}, inplace=True)

# %%
df
# Out:
#      Name Class
# 0   Ahmad  BSCS
# 1     Ali  BSIT
# 2  Hassan  BSSE

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      str
#  1   Class   3 non-null      str
# dtypes: str(2)
# memory usage: 180.0 bytes

# %%
df.describe()
# Out:
#          Name Class
# count       3     3
# unique      3     3
# top     Ahmad  BSCS
# freq        1     1

# %%
df.to_csv('Student.csv', index=False)
