# %%
import pandas as pd

# %%
df = pd.read_csv('Student.csv')

# %%
df
# Out:
#      Name Class
# 0   Ahmad  BSCS
# 1     Ali  BSIT
# 2  Hassan  BSSE

# %%
df.loc[df.Name=='Ali'] #it will select particular row
# Out:
#   Name Class
# 1  Ali  BSIT

# %%
df[['Name']] #it will select a column
# Out:
#      Name
# 0   Ahmad
# 1     Ali
# 2  Hassan
